# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
matplotlib.rcParams["figure.figsize"]=(20,10)
df=pd.read_csv("/content/Worksheet in E-Commerce _Command Center (1).xlsm - List of Orders.csv")
df1=pd.read_csv("/content/Worksheet in E-Commerce _Command Center (2).xlsm - Order Details.csv")
df2=pd.read_csv("/content/Worksheet in E-Commerce _Command Center (3).xlsm - Sales target.csv")

# %%
df.head(5)
# Out:
#   Order ID Order Date CustomerName           State       City
# 0  B-25601   1/4/2018       Bharat         Gujarat  Ahmedabad
# 1  B-25602   1/4/2018        Pearl     Maharashtra       Pune
# 2  B-25603   3/4/2018        Jahan  Madhya Pradesh     Bhopal
# 3  B-25604   3/4/2018       Divsha       Rajasthan     Jaipur
# 4  B-25605   5/4/2018      Kasheen     West Bengal    Kolkata

# %%
import datetime as dt
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Order Date'] = df['Order Date'].dt.strftime('%m-%d-%Y')
df.head()
# Out:
#   Order ID  Order Date CustomerName           State       City
# 0  B-25601  01-04-2018       Bharat         Gujarat  Ahmedabad
# 1  B-25602  01-04-2018        Pearl     Maharashtra       Pune
# 2  B-25603  03-04-2018        Jahan  Madhya Pradesh     Bhopal
# 3  B-25604  03-04-2018       Divsha       Rajasthan     Jaipur
# 4  B-25605  05-04-2018      Kasheen     West Bengal    Kolkata

# %%
df10=df
df10.head()
# Out:
#   Order ID  Order Date CustomerName           State       City
# 0  B-25601  01-04-2018       Bharat         Gujarat  Ahmedabad
# 1  B-25602  01-04-2018        Pearl     Maharashtra       Pune
# 2  B-25603  03-04-2018        Jahan  Madhya Pradesh     Bhopal
# 3  B-25604  03-04-2018       Divsha       Rajasthan     Jaipur
# 4  B-25605  05-04-2018      Kasheen     West Bengal    Kolkata

# %%
df1.head(5)
# Out:
#   Order ID  Amount  Profit  Quantity     Category      Sub-Category
# 0  B-25601    1275   -1148         7    Furniture         Bookcases
# 1  B-25601      66     -12         5     Clothing             Stole
# 2  B-25601       8      -2         3     Clothing       Hankerchief
# 3  B-25601      80     -56         4  Electronics  Electronic Games
# 4  B-25602     168    -111         2  Electronics            Phones

# %%
df2.rename(columns={'Month of Order Date':'Month'},inplace=True)
df2.head()
# Out:
#     Month   Category  Target
# 0  18-Apr  Furniture   10400
# 1  18-May  Furniture   10500
# 2  18-Jun  Furniture   10600
# 3  18-Jul  Furniture   10800
# 4  18-Aug  Furniture   10900

# %%
df2[['Day','Mon']]=df2['Month'].str.split('-',expand=True)

# %%
df2.head()
# Out:
#     Month   Category  Target Day  Mon
# 0  18-Apr  Furniture   10400  18  Apr
# 1  18-May  Furniture   10500  18  May
# 2  18-Jun  Furniture   10600  18  Jun
# 3  18-Jul  Furniture   10800  18  Jul
# 4  18-Aug  Furniture   10900  18  Aug

# %%
df2['Mon']=pd.to_datetime(df2.Mon,format='%b').dt.month

# %%
df2.head()
# Out:
#     Month   Category  Target Day  Mon
# 0  18-Apr  Furniture   10400  18    4
# 1  18-May  Furniture   10500  18    5
# 2  18-Jun  Furniture   10600  18    6
# 3  18-Jul  Furniture   10800  18    7
# 4  18-Aug  Furniture   10900  18    8

# %%
df1.isna().sum()
# Out:
# Order ID        0
# Amount          0
# Profit          0
# Quantity        0
# Category        0
# Sub-Category    0
# dtype: int64

# %%
df2.isna().sum()
# Out:
# Month       0
# Category    0
# Target      0
# Day         0
# Mon         0
# dtype: int64

# %%
new_df = df.dropna()
print(new_df.to_string())
# Out:
#     Order ID  Order Date  CustomerName              State                City
# 0    B-25601  01-04-2018        Bharat            Gujarat           Ahmedabad
# 1    B-25602  01-04-2018         Pearl        Maharashtra                Pune
# 2    B-25603  03-04-2018         Jahan     Madhya Pradesh              Bhopal
# 3    B-25604  03-04-2018        Divsha          Rajasthan              Jaipur
# 4    B-25605  05-04-2018       Kasheen        West Bengal             Kolkata
# 5    B-25606  06-04-2018         Hazel          Karnataka           Bangalore
# 6    B-25607  06-04-2018      Sonakshi  Jammu and Kashmir             Kashmir
# 7    B-25608  08-04-2018       Aarushi         Tamil Nadu             Chennai
# 8    B-25609  09-04-2018        Jitesh      Uttar Pradesh             Lucknow
# 9    B-25610  09-04-2018        Yogesh              Bihar               Patna
# 10   B-25611  11-04-2018         Anita            Kerala   Thiruvananthapuram
# ...

# %%
new_df1 = df1.dropna()
print(new_df1.to_string())
# Out:
#      Order ID  Amount  Profit  Quantity     Category      Sub-Category
# 0     B-25601    1275   -1148         7    Furniture         Bookcases
# 1     B-25601      66     -12         5     Clothing             Stole
# 2     B-25601       8      -2         3     Clothing       Hankerchief
# 3     B-25601      80     -56         4  Electronics  Electronic Games
# 4     B-25602     168    -111         2  Electronics            Phones
# 5     B-25602     424    -272         5  Electronics            Phones
# 6     B-25602    2617    1151         4  Electronics            Phones
# 7     B-25602     561     212         3     Clothing             Saree
# 8     B-25602     119      -5         8     Clothing             Saree
# 9     B-25603    1355     -60         5     Clothing          Trousers
# 10    B-25603      24     -30         1    Furniture            Chairs
# 11    B-25603     193    -166         3     Clothing             Saree
# ...

# %%
new_df2 = df2.dropna()
print(new_df2.to_string())
# Out:
#      Month     Category  Target Day  Mon
# 0   18-Apr    Furniture   10400  18    4
# 1   18-May    Furniture   10500  18    5
# 2   18-Jun    Furniture   10600  18    6
# 3   18-Jul    Furniture   10800  18    7
# 4   18-Aug    Furniture   10900  18    8
# 5   18-Sep    Furniture   11000  18    9
# 6   18-Oct    Furniture   11100  18   10
# 7   18-Nov    Furniture   11300  18   11
# 8   18-Dec    Furniture   11400  18   12
# 9   19-Jan    Furniture   11500  19    1
# 10  19-Feb    Furniture   11600  19    2
# 11  19-Mar    Furniture   11800  19    3
# 12  18-Apr     Clothing   12000  18    4
# 13  18-May     Clothing   12000  18    5
# 14  18-Jun     Clothing   12000  18    6
# 15  18-Jul     Clothing   14000  18    7
# 16  18-Aug     Clothing   14000  18    8
# 17  18-Sep     Clothing   14000  18    9
# 18  18-Oct     Clothing   16000  18   10
# 19  18-Nov     Clothing   16000  18   11
# 20  18-Dec     Clothing   16000  18   12
# 21  19-Jan     Clothing   16000  19    1
# ...

# %%
print(new_df1.duplicated())
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1495    False
# 1496    False
# 1497    False
# 1498    False
# 1499    False
# Length: 1500, dtype: bool

# %%
print(new_df1.duplicated())
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1495    False
# 1496    False
# 1497    False
# 1498    False
# 1499    False
# Length: 1500, dtype: bool

# %%
print(new_df2.duplicated())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# dtype: bool

# %%
new_df.drop_duplicates(inplace = True)
print(new_df)
# Out:
#     Order ID  Order Date CustomerName              State       City
# 0    B-25601  01-04-2018       Bharat            Gujarat  Ahmedabad
# 1    B-25602  01-04-2018        Pearl        Maharashtra       Pune
# 2    B-25603  03-04-2018        Jahan     Madhya Pradesh     Bhopal
# 3    B-25604  03-04-2018       Divsha          Rajasthan     Jaipur
# 4    B-25605  05-04-2018      Kasheen        West Bengal    Kolkata
# ..       ...         ...          ...                ...        ...
# 495  B-26096  03-28-2019       Atharv        West Bengal    Kolkata
# 496  B-26097  03-28-2019         Vini          Karnataka  Bangalore
# 497  B-26098  03-29-2019        Pinky  Jammu and Kashmir    Kashmir
# 498  B-26099  03-30-2019       Bhishm        Maharashtra     Mumbai
# 499  B-26100  03-31-2019       Hitika     Madhya Pradesh     Indore
#
# [500 rows x 5 columns]

# %%
new_df1.drop_duplicates(inplace = True)
print(new_df1)
# Out:
#      Order ID  Amount  Profit  Quantity     Category      Sub-Category
# 0     B-25601    1275   -1148         7    Furniture         Bookcases
# 1     B-25601      66     -12         5     Clothing             Stole
# 2     B-25601       8      -2         3     Clothing       Hankerchief
# 3     B-25601      80     -56         4  Electronics  Electronic Games
# 4     B-25602     168    -111         2  Electronics            Phones
# ...       ...     ...     ...       ...          ...               ...
# 1495  B-26099     835     267         5  Electronics            Phones
# 1496  B-26099    2366     552         5     Clothing          Trousers
# 1497  B-26100     828     230         2    Furniture            Chairs
# 1498  B-26100      34      10         2     Clothing           T-shirt
# 1499  B-26100      72      16         2     Clothing             Shirt
#
# [1500 rows x 6 columns]

# %%
new_df2.drop_duplicates(inplace = True)
print(new_df2)
# Out:
#      Month     Category  Target Day  Mon
# 0   18-Apr    Furniture   10400  18    4
# 1   18-May    Furniture   10500  18    5
# 2   18-Jun    Furniture   10600  18    6
# 3   18-Jul    Furniture   10800  18    7
# 4   18-Aug    Furniture   10900  18    8
# 5   18-Sep    Furniture   11000  18    9
# 6   18-Oct    Furniture   11100  18   10
# 7   18-Nov    Furniture   11300  18   11
# 8   18-Dec    Furniture   11400  18   12
# 9   19-Jan    Furniture   11500  19    1
# 10  19-Feb    Furniture   11600  19    2
# 11  19-Mar    Furniture   11800  19    3
# 12  18-Apr     Clothing   12000  18    4
# 13  18-May     Clothing   12000  18    5
# 14  18-Jun     Clothing   12000  18    6
# 15  18-Jul     Clothing   14000  18    7
# 16  18-Aug     Clothing   14000  18    8
# 17  18-Sep     Clothing   14000  18    9
# 18  18-Oct     Clothing   16000  18   10
# 19  18-Nov     Clothing   16000  18   11
# 20  18-Dec     Clothing   16000  18   12
# 21  19-Jan     Clothing   16000  19    1
# ...

# %%
dff=pd.merge(new_df, new_df1)
dff
# Out:
#      Order ID  Order Date CustomerName           State       City  Amount  \
# 0     B-25601  01-04-2018       Bharat         Gujarat  Ahmedabad    1275
# 1     B-25601  01-04-2018       Bharat         Gujarat  Ahmedabad      66
# 2     B-25601  01-04-2018       Bharat         Gujarat  Ahmedabad       8
# 3     B-25601  01-04-2018       Bharat         Gujarat  Ahmedabad      80
# 4     B-25602  01-04-2018        Pearl     Maharashtra       Pune     168
# ...       ...         ...          ...             ...        ...     ...
# 1495  B-26099  03-30-2019       Bhishm     Maharashtra     Mumbai     835
# 1496  B-26099  03-30-2019       Bhishm     Maharashtra     Mumbai    2366
# 1497  B-26100  03-31-2019       Hitika  Madhya Pradesh     Indore     828
# 1498  B-26100  03-31-2019       Hitika  Madhya Pradesh     Indore      34
# 1499  B-26100  03-31-2019       Hitika  Madhya Pradesh     Indore      72
#
#       Profit  Quantity     Category      Sub-Category
# ...

# %%
df11=dff
df11[['Day','Mon','Year']]=df11['Order Date'].str.split('-',expand=True)

# %%
df11.head()
# Out:
#   Order ID  Order Date CustomerName        State       City  Amount  Profit  \
# 0  B-25601  01-04-2018       Bharat      Gujarat  Ahmedabad    1275   -1148
# 1  B-25601  01-04-2018       Bharat      Gujarat  Ahmedabad      66     -12
# 2  B-25601  01-04-2018       Bharat      Gujarat  Ahmedabad       8      -2
# 3  B-25601  01-04-2018       Bharat      Gujarat  Ahmedabad      80     -56
# 4  B-25602  01-04-2018        Pearl  Maharashtra       Pune     168    -111
#
#    Quantity     Category      Sub-Category Day Mon  Year
# 0         7    Furniture         Bookcases  01  04  2018
# 1         5     Clothing             Stole  01  04  2018
# 2         3     Clothing       Hankerchief  01  04  2018
# 3         4  Electronics  Electronic Games  01  04  2018
# 4         2  Electronics            Phones  01  04  2018

# %%
df2.head()
# Out:
#     Month   Category  Target Day  Mon
# 0  18-Apr  Furniture   10400  18    4
# 1  18-May  Furniture   10500  18    5
# 2  18-Jun  Furniture   10600  18    6
# 3  18-Jul  Furniture   10800  18    7
# 4  18-Aug  Furniture   10900  18    8

# %%
dfff=dff.groupby('Order ID').sum()
dfff.reset_index(inplace=True)
dfff
# Out:
#     Order ID  Amount  Profit  Quantity
# 0    B-25601    1429   -1218        19
# 1    B-25602    3889     975        22
# 2    B-25603    2025    -180        25
# 3    B-25604     222      22        11
# 4    B-25605      75       0         7
# ..       ...     ...     ...       ...
# 495  B-26096    1091     121        18
# 496  B-26097    1688    -504        23
# 497  B-26098    1189     350        21
# 498  B-26099    3417     859        15
# 499  B-26100     934     256         6
#
# [500 rows x 4 columns]

# %%
n=len(pd.unique(df['Order ID']))
n
# Out:
# 500

# %%
dfff.plot(x="Order ID",y="Profit")

# %%
dff['Category'].value_counts().head(10).plot.pie()
plt.gca().set_aspect('equal')

# %%
dff['Sub-Category'].value_counts().head(10).plot.pie()
plt.gca().set_aspect('equal')

# %%
dfff.plot(x="Order ID", y=["Quantity","Profit","Amount"])

# %%
dff.plot(kind = 'scatter', x = 'Profit', y = 'State')
plt.show()

# %%
dff.plot(kind = 'scatter', x = 'Profit', y = 'Category')
plt.show()

# %%
dff.plot(kind = 'scatter', x = 'Profit', y = 'Sub-Category')
plt.show()

# %%
fig, ax = plt.subplots(figsize =(10, 7))
ax.hist("Profit", bins = [0, 25, 50, 75, 100])
plt.show()

# %%
dff['Order Date'] = pd.to_datetime(dff['Order Date'])
a=dff.groupby(dff['Order Date'].dt.strftime('%B'))['Profit'].sum().sort_values()
a.plot(kind='bar')

# %%
df4=dff.groupby('State').sum()
df4.reset_index(inplace=True)
df4
# Out:
#                 State  Amount  Profit  Quantity
# 0      Andhra Pradesh   13256    -496       146
# 1               Bihar   12943    -321       206
# 2               Delhi   22531    2987       277
# 3                 Goa    6705     370       145
# 4             Gujarat   21058     465       328
# 5             Haryana    8863    1325       111
# 6    Himachal Pradesh    8666     656       113
# 7   Jammu and Kashmir   10829       8       177
# 8           Karnataka   15058     645       180
# 9             Kerala    13459    1871       157
# 10     Madhya Pradesh  105140    5551      1360
# 11        Maharashtra   95348    6176      1056
# 12           Nagaland   11903     148       173
# 13             Punjab   16786    -609       216
# 14          Rajasthan   21149    1257       282
# 15             Sikkim    5276     401        93
# 16         Tamil Nadu    6087   -2216        91
# 17      Uttar Pradesh   22359    3237       288
# 18        West Bengal   14086    2500       216

# %%
df5 = df4.sort_values('Profit')
df5.plot(x='State',y='Profit',kind='bar')

# %%
n=len(pd.unique(dff['CustomerName']))
n
# Out:
# 332

# %%
df6=dff.groupby('CustomerName').sum()
df6.reset_index(inplace=True)
df6
# Out:
#     CustomerName  Amount  Profit  Quantity
# 0      Aakanksha      74     -18         8
# 1        Aarushi    4701   -1669        49
# 2         Aashna    1931     376        32
# 3         Aastha    3276     873        28
# 4         Aayush     556     -38        18
# ..           ...     ...     ...       ...
# 327         Wale     130     -97         8
# 328       Yaanvi    9177     488        71
# 329         Yash     791    -647        21
# 330       Yogesh    5421    -347        55
# 331       Yohann    1314     342         3
#
# [332 rows x 4 columns]

# %%
x=df6['CustomerName'].min()
x
# Out:
# 'Aakanksha'

# %%
df7=dff.groupby('Category').sum()
df7.reset_index(inplace=True)
df7
# Out:
#       Category  Amount  Profit  Quantity
# 0     Clothing  139054   11163      3516
# 1  Electronics  165267   10494      1154
# 2    Furniture  127181    2298       945

# %%
df8=dff.groupby('Sub-Category').sum()
df8.reset_index(inplace=True)
df8
# Out:
#         Sub-Category  Amount  Profit  Quantity
# 0        Accessories   21728    3559       262
# 1          Bookcases   56861    4888       297
# 2             Chairs   34222     577       277
# 3   Electronic Games   39168   -1236       297
# 4        Furnishings   13484     844       310
# 5        Hankerchief   14608    2098       754
# 6              Kurti    3361     181       164
# 7           Leggings    2106     260       186
# 8             Phones   46119    2207       304
# 9           Printers   58252    5964       291
# 10             Saree   53511     352       782
# 11             Shirt    7555    1131       271
# 12             Skirt    1946     235       248
# 13             Stole   18546    2559       671
# 14           T-shirt    7382    1500       305
# 15            Tables   22614   -4011        61
# 16          Trousers   30039    2847       135

# %%
x=df7['Category'].max()
x
# Out:
# 'Furniture'

# %%
x=df8['Sub-Category'].max()
x
# Out:
# 'Trousers'

# %%
print(dfff.corr())
# Out:
#             Amount    Profit  Quantity
# Amount    1.000000  0.316259  0.733994
# Profit    0.316259  1.000000  0.176259
# Quantity  0.733994  0.176259  1.000000

# %%
print(dfff.cov())
# Out:
#                 Amount         Profit     Quantity
# Amount    1.217224e+06  113669.032425  8189.864810
# Profit    1.136690e+05  106127.609118   580.716132
# Quantity  8.189865e+03     580.716132   102.281663

# %%
dfff.plot()
plt.show()

# %%
corrMatrix = dfff.corr()
sns.heatmap(corrMatrix, annot=True)
plt.show()
